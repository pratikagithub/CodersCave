# %% [markdown]
# ### PHASE 1:-

# %% [markdown]
# ### Breast Cancer Prediction Dataset

# %% [markdown]
# Breast cancer is the most common cancer amongst women in the world. it accounts for 25% of all cancer cases and affected over
# 2.1 Million people in 2015 alone. It starts when cells in the breast begin to grow out of control. These cells usually form
# tumors that can be seen via X-ray or felt as lumps in the breast area.

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('C:\\Users\\HP\\Downloads\\data.csv')

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.shape
# Out:
# (569, 32)

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave_points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave_points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %% [markdown]
# ### Cleaning Data

# %%
#missing values
cols_with_missing=[col for col in df.columns
                  if df[col].isnull().any()]

# %%
missing_value=(df.isnull().sum())

# %%
missing_value
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave_points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave_points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave_points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
df=df.drop(cols_with_missing,axis=1)

# %%
print(df['diagnosis'].describe())
# Out:
# count     569
# unique      2
# top         B
# freq      357
# Name: diagnosis, dtype: object

# %%
print(df.head())
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ### Categorical Variables

# %%
diagnosis_mapper={"B":0,"M":1}
df['diagnosis']=df['diagnosis'].replace(diagnosis_mapper)

# %%
df=df.drop("id",axis=1)

# %%
df
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0            1        17.99         10.38          122.80     1001.0
# 1            1        20.57         17.77          132.90     1326.0
# 2            1        19.69         21.25          130.00     1203.0
# 3            1        11.42         20.38           77.58      386.1
# 4            1        20.29         14.34          135.10     1297.0
# ..         ...          ...           ...             ...        ...
# 564          1        21.56         22.39          142.00     1479.0
# 565          1        20.13         28.25          131.20     1261.0
# 566          1        16.60         28.08          108.30      858.1
# 567          1        20.60         29.33          140.10     1265.0
# 568          0         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# ...

# %% [markdown]
# ### Modeling

# %%
from sklearn.neighbors import NearestCentroid, KNeighborsClassifier

# %%
def get_score_nearest_centroid():
    scores=cross_val_score(NearestCentroid(),x,y,cv=3,scoring='accuracy')
    return scores.mean()

# %%
def get_score_k_neighbors(n_neighbors):
    scores=cross_val_score(KNeighborsClassifier(n_neighbors=n_neighbors),x,y,cv=3,scoring='accuracy')
    return scores.mean()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
def get_score_random_forest(n_estimators):
    scores=cross_val_score(RandomForestClassifier(n_estimators=n_estimators),x,y,cv=3,scoring='accuracy')
    return scores.mean()

# %%
from sklearn import svm

# %%
def get_score_svm(kernel):
    clf=svm.SVC(kernel=kernel, C=1)
    scores=cross_val_score(clf,x,y,cv=3,scoring='accuracy')
    return scores.mean()

# %% [markdown]
# ### Prediction

# %%
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline

# %%
x=df.copy()
y=df['diagnosis']
x.drop(['diagnosis'],axis=1,inplace=True)

kernels={"linear","poly","rbf","sigmoid"}
results={}

# %%
# adding result for support vector machines
for i, kernel in enumerate(kernels):
    results[i]=get_score_svm(kernel)*100

# %%
# adding result for Nearest Neighbors approaches
results[4]=get_score_nearest_centroid()*100
resultsKNeighbors={}

# %%
# optimize the best number of neighbors
for i in range(1,25):
    resultsKNeighbors[i-1]=get_score_k_neighbors(i)*100
    results[5]=max(resultsKNeighbors.values())
    resultsRandomForest={}
    index=0

# %%
# optimize the best number of estimators
for i in range(10,40):
    resultsRandomForest[index]=get_score_random_forest(i)*100
    index=index+1
    results[6]=max(resultsRandomForest.values())

# %%
print(results)
# Out:
# {0: 95.0784368328228, 1: 47.270955165692, 2: 90.51610507750858, 3: 91.04334911352456, 4: 89.11073981249422, 5: 93.1486122714193, 6: 96.48473034437947}

# %% [markdown]
# ### Data Visualization

# %%
import matplotlib.pyplot as plt
classifier_labels=["linear","poly","rbf","sigmoid","NearestCentroid","KNeighbors","RandomForest"]
fig, ax=plt.subplots()
ax.bar(list(results.keys()),list(results.values()))
plt.xticks(list(results.keys()),classifier_labels)

# set the X ticks and labels
ax.set_ylabel('Accuracy(%)')
ax.set_title('Accuracy by classifier')
fig.set_size_inches(14,8)
plt.show()

# %% [markdown]
# we can see that my most acccurate is the Random Forest with 96-97% Accuracy.
